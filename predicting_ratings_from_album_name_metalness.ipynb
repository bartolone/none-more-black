# %%
import pandas as pd
import numpy as np
import pickle 
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# First we'll read in the cleaned album files -- 8,907 in total. We have the following columns:
# * Band name
# * Album name
# * Number of songs on the album
# * Release year
# * Editor review score
# * Number of user reviewers
# * Average user review score
# * Album metalness score
# * Song titles metalness score
# * Band name metalness score
#
# Each metalness score is calculated in three different ways across words in the item: mean metalness score, sum of metalness scores, and the sum of metalness scores divided by the number of words in the item plus one.
#
# This information was scraped from MetalStorm.net in October 2018. I have not made the data available (nor the code used to scrape and clean it) in this repo for copyright reasons.
#
# Metalness scores are calculated using Iain Barr's metalness index (https://github.com/ijmbarr/pythonic-metal)

# %%
model_df = pd.read_pickle("metal_for_modeling.pkl")

# %% [markdown]
# # Metalness ratings eyeball check
#
# As a reasonableness check, here are the 10 most and least metal album titles for each of the three methods I used to calculate album title metalness.
#
# First, the sum of metalness scores:

# %%
print(model_df.sort_values(by='album_metalness_sum', ascending=False).album.head(10))
print(model_df.sort_values(by='album_metalness_sum').album.head(10))
# Out:
# 2045     As Blood Rains From The Sky...We Walk The Path...
# 14522                  Time Will Die And Love Will Bury It
# 2133                               Rage Of The Blood Beast
# 7014                      Let Mortal Heroes Sing Your Fame
# 10755                 Hear Nothing See Nothing Say Nothing
# 2638                   The Wind Blows Witches From The Sky
# 10337                 Woods 5: Grey Skies & Electric Light
# 157                                     Scream Bloody Gore
# 4814                      Beyond Darkness And Hell We Come
# 9152                                  Kiss The Sun Goodbye
# Name: album, dtype: object
# 3520     Doomsday For The Deceiver 20th Anniversary Spe...
# 4942                             20 Year Anniversary Party
# 13832                              Nato Per Ragioni Ignote
# 2937     Medical Malpractioners Of Pathological Pervers...
# 9124                           Prolonged Active Antagonism
# 14643                                The Density Parameter
# 4009                                        I Am Jim Jones
# 125                           Unorthodox Creative Criteria
# 2052                              Available For Propaganda
# 2457                            Credit Where Credit Is Due
# Name: album, dtype: object

# %% [markdown]
# Next, the mean metalness scores:

# %%
print(model_df.sort_values(by='album_metalness_mean', ascending=False).album.head(10))
print(model_df.sort_values(by='album_metalness_mean').album.head(10))
# Out:
# 11115                   Burn
# 8063                    Burn
# 517      As The Palaces Burn
# 11545            In My Veins
# 11271               Eternity
# 4100                Eternity
# 801             All Eternity
# 724                 Eternity
# 1249                Eternity
# 6387                 Breathe
# Name: album, dtype: object
# 5755     Crumb's Crunchy Delights Organization
# 7185                             Carte Blanche
# 13165                     District Of Dystopia
# 4742                Blackened Theological Tome
# 1457                         666 International
# 891                                  Section X
# 3079                 Chainsaw Cesarean Section
# 2031                       Martie Peters Group
# 2952      Arrangements For Fulminating Vective
# 13486                                   Alaska
# Name: album, dtype: object

# %% [markdown]
# Finally, our compromise version: the sum of the metalness scores divided by the number of words plus one:

# %%
print(model_df.sort_values(by='album_metalness_sum_div_len2', ascending=False).album.head(10))
print(model_df.sort_values(by='album_metalness_sum_div_len2').album.head(10))
# Out:
# 2133     Rage Of The Blood Beast
# 7803            Sword Of Revenge
# 10518            Tears And Ashes
# 2857              Burn Me Wicked
# 4101              Bury The Ashes
# 9250      From Chaos To Eternity
# 10504      The Reign Of Darkness
# 13818     Trapped In The Shadows
# 157           Scream Bloody Gore
# 730            Ashes Of The Wake
# Name: album, dtype: object
# 5755                 Crumb's Crunchy Delights Organization
# 3520     Doomsday For The Deceiver 20th Anniversary Spe...
# 13832                              Nato Per Ragioni Ignote
# 7185                                         Carte Blanche
# 13165                                 District Of Dystopia
# 4742                            Blackened Theological Tome
# 1457                                     666 International
# 3079                             Chainsaw Cesarean Section
# 891                                              Section X
# 2031                                   Martie Peters Group
# Name: album, dtype: object

# %% [markdown]
# All of these versions look pretty good to me, although the compromise version looks the best based on the eye test.
#
# We'll use all three in our modeling to see if any version predicts better than the others.
#
# The above was fun but we don't need the band and album names for modeling.

# %%
model_df.drop(columns = ['band', 'album'], inplace = True)
model_df.dtypes
# Out:
# num_songs                           float64
# release_year                        float64
# review_score_num                    float64
# user_review_num                     float64
# user_review_score_num               float64
# album_metalness_sum                 float64
# album_metalness_mean                float64
# album_metalness_sum_div_len2        float64
# songtitle_metalness_sum             float64
# songtitle_metalness_mean            float64
# songtitle_metalness_sum_div_len2    float64
# bandname_metalness_sum              float64
# bandname_metalness_mean             float64
# bandname_metalness_sum_div_len2     float64
# dtype: object

# %% [markdown]
# Let's go ahead and standardize all of the numeric variables for modeling flexibility.

# %%
for col in model_df.columns:
    col_zscore = col + '_zscore'
    model_df[col_zscore] = (model_df[col] - model_df[col].mean())/model_df[col].std()

model_df.drop(columns = ['num_songs', 'release_year', 'review_score_num', 'user_review_num', 'user_review_score_num', 
                        'album_metalness_sum', 'album_metalness_mean', 'album_metalness_sum_div_len2', 
                        'songtitle_metalness_sum', 'songtitle_metalness_mean', 'songtitle_metalness_sum_div_len2',
                        'bandname_metalness_sum', 'bandname_metalness_mean', 'bandname_metalness_sum_div_len2'], 
              inplace = True)

model_df.head(10)
# Out:
#     num_songs_zscore  release_year_zscore  review_score_num_zscore  \
# 1           0.264812            -0.668986                -0.312380
# 2           1.682120            -0.668986                 0.519286
# 3           0.264812            -1.407541                 0.269787
# 4           0.264812            -1.112119                 0.602453
# 5           0.264812            -0.668986                 0.768786
# 7          -0.018649            -0.668986                 0.602453
# 9           3.666351            -1.112119                 0.935120
# 10          0.264812            -0.964408                 1.766786
# 11          0.264812            -0.816697                 0.935120
# 12         -0.302111            -1.702963                 1.350953
#
#     user_review_num_zscore  user_review_score_num_zscore  \
# 1                 3.836850                      0.891848
# 2                 0.785471                      0.879380
# 3                -0.235790                      0.480412
# 4                -0.219252                      0.218588
# 5                -0.153097                      0.779638
# 7                -0.074538                      0.081443
# 9                -0.004249                      0.941719
# 10               -0.099346                      0.891848
# 11               -0.306079                      0.305863
# 12                0.690374                      0.131314
#
#     album_metalness_sum_zscore  album_metalness_mean_zscore  \
# 1                    -1.232209                    -1.131751
# 2                     0.471374                     0.313905
# 3                     0.414454                     0.265602
# 4                     0.696469                     0.504920
# 5                     0.832484                     0.620341
# 7                     1.162869                     0.396314
# 9                    -1.608704                    -1.451244
# 10                   -1.608704                    -1.451244
# 11                    0.175108                     0.737455
# 12                   -0.620277                    -0.612468
#
#     album_metalness_sum_div_len2_zscore  songtitle_metalness_sum_zscore  \
# 1                             -1.227162                        1.547429
# 2                              0.420432                        2.094772
# 3                              0.365382                        0.853938
# 4                              0.638129                        0.656205
# 5                              0.769673                        0.842641
# 7                              0.658065                       -1.403473
# 9                             -1.591283                        3.771442
# 10                            -1.591283                        1.036765
# 11                             0.518524                        0.410804
# 12                            -0.635342                        0.419735
#
#     songtitle_metalness_mean_zscore  songtitle_metalness_sum_div_len2_zscore  \
# 1                          1.028148                                 1.234784
# 2                          0.320208                                 0.492251
# 3                          0.880424                                 1.028438
# 4                          0.495786                                 0.616554
# 5                          0.282350                                 0.405901
# 7                         -2.124611                                -2.155921
# 9                          0.251359                                 0.440831
# 10                         0.718805                                 0.876841
# 11                         0.243198                                 0.335908
# 12                         0.770333                                 0.869283
#
#     bandname_metalness_sum_zscore  bandname_metalness_mean_zscore  \
# 1                       -0.355976                       -0.355177
# 2                        1.095925                        0.351052
# 3                       -0.355976                       -0.355177
# 4                       -0.355976                       -0.355177
# 5                       -0.355976                       -0.355177
# 7                       -0.355976                       -0.355177
# 9                       -0.984158                       -0.813515
# 10                      -0.984158                       -0.813515
# 11                      -0.355976                       -0.355177
# 12                      -0.355976                       -0.355177
#
#     bandname_metalness_sum_div_len2_zscore
# 1                                -0.362025
# 2                                 0.578906
# 3                                -0.362025
# 4                                -0.362025
# 5                                -0.362025
# 7                                -0.362025
# 9                                -0.904830
# 10                               -0.904830
# 11                               -0.362025
# 12                               -0.362025

# %% [markdown]
# # Modeling
#
# Let's start with a correlation matrix using our standardized variables. Our two potential outputs are review_score_num_zscore and user_review_score_num_zscore, so let's first check for missing values in each column.
#
# We have 712 albums with no editor review score and 1,544 with no user review score. We're going to drop the rows with missing user review scores since they are also missing the number of user reviewers, one of our input variables.
#
# We'll keep the rows with missing editor review scores for the time being, although we will have to drop them from any model we create that attempts to predict editor review scores instead of user review scores.
#
# There's not much here in the correlation matrix ...

# %%
print("Missing editor review scores: ", model_df['review_score_num_zscore'].isnull().sum())
print("Missing user review scores: ", model_df['user_review_score_num_zscore'].isnull().sum())

model_df.dropna(subset = ['user_review_score_num_zscore'], inplace=True)
print("Missing user review scores after drops: ", model_df['user_review_num_zscore'].isnull().sum())
print("Number of albums remaining: ", model_df.num_songs_zscore.count())

model_df.corr()
# Out:
# Missing editor review scores:  712
# Missing user review scores:  1544
# Missing user review scores after drops:  0
# Number of albums remaining:  7363
#                                          num_songs_zscore  \
# num_songs_zscore                                 1.000000
# release_year_zscore                             -0.063847
# review_score_num_zscore                         -0.035927
# user_review_num_zscore                           0.038733
# user_review_score_num_zscore                    -0.030990
# album_metalness_sum_zscore                       0.019101
# album_metalness_mean_zscore                      0.022468
# album_metalness_sum_div_len2_zscore              0.023494
# songtitle_metalness_sum_zscore                   0.449803
# songtitle_metalness_mean_zscore                  0.068983
# songtitle_metalness_sum_div_len2_zscore          0.153409
# bandname_metalness_sum_zscore                    0.020011
# bandname_metalness_mean_zscore                   0.020656
# bandname_metalness_sum_div_len2_zscore           0.020677
#
#                                          release_year_zscore  \
# num_songs_zscore                                   -0.063847
# release_year_zscore                                 1.000000
# review_score_num_zscore                            -0.196096
# user_review_num_zscore                             -0.312902
# user_review_score_num_zscore                       -0.231317
# album_metalness_sum_zscore                         -0.042594
# album_metalness_mean_zscore                        -0.038621
# album_metalness_sum_div_len2_zscore                -0.041059
# songtitle_metalness_sum_zscore                     -0.084655
# songtitle_metalness_mean_zscore                    -0.045006
# songtitle_metalness_sum_div_len2_zscore            -0.056918
# bandname_metalness_sum_zscore                      -0.019313
# bandname_metalness_mean_zscore                     -0.029553
# bandname_metalness_sum_div_len2_zscore             -0.026162
#
#                                          review_score_num_zscore  \
# num_songs_zscore                                       -0.035927
# release_year_zscore                                    -0.196096
# review_score_num_zscore                                 1.000000
# user_review_num_zscore                                  0.203497
# user_review_score_num_zscore                            0.521398
# album_metalness_sum_zscore                              0.004268
# album_metalness_mean_zscore                            -0.001382
# album_metalness_sum_div_len2_zscore                    -0.000846
# songtitle_metalness_sum_zscore                         -0.046577
# songtitle_metalness_mean_zscore                        -0.022281
# songtitle_metalness_sum_div_len2_zscore                -0.028331
# bandname_metalness_sum_zscore                           0.008874
# bandname_metalness_mean_zscore                          0.009939
# bandname_metalness_sum_div_len2_zscore                  0.009673
#
#                                          user_review_num_zscore  \
# num_songs_zscore                                       0.038733
# release_year_zscore                                   -0.312902
# review_score_num_zscore                                0.203497
# user_review_num_zscore                                 1.000000
# user_review_score_num_zscore                           0.253465
# album_metalness_sum_zscore                             0.016729
# album_metalness_mean_zscore                            0.012479
# album_metalness_sum_div_len2_zscore                    0.014715
# songtitle_metalness_sum_zscore                         0.063567
# songtitle_metalness_mean_zscore                        0.032759
# songtitle_metalness_sum_div_len2_zscore                0.041563
# bandname_metalness_sum_zscore                          0.023605
# bandname_metalness_mean_zscore                         0.048980
# bandname_metalness_sum_div_len2_zscore                 0.039552
#
#                                          user_review_score_num_zscore  \
# num_songs_zscore                                            -0.030990
# release_year_zscore                                         -0.231317
# review_score_num_zscore                                      0.521398
# user_review_num_zscore                                       0.253465
# user_review_score_num_zscore                                 1.000000
# album_metalness_sum_zscore                                   0.007253
# album_metalness_mean_zscore                                  0.008844
# album_metalness_sum_div_len2_zscore                          0.008200
# songtitle_metalness_sum_zscore                               0.001452
# songtitle_metalness_mean_zscore                              0.005876
# songtitle_metalness_sum_div_len2_zscore                      0.007654
# bandname_metalness_sum_zscore                                0.021357
# bandname_metalness_mean_zscore                               0.037260
# bandname_metalness_sum_div_len2_zscore                       0.031936
#
#                                          album_metalness_sum_zscore  \
# num_songs_zscore                                           0.019101
# release_year_zscore                                       -0.042594
# review_score_num_zscore                                    0.004268
# user_review_num_zscore                                     0.016729
# user_review_score_num_zscore                               0.007253
# album_metalness_sum_zscore                                 1.000000
# album_metalness_mean_zscore                                0.877294
# album_metalness_sum_div_len2_zscore                        0.949025
# songtitle_metalness_sum_zscore                             0.298502
# songtitle_metalness_mean_zscore                            0.264370
# songtitle_metalness_sum_div_len2_zscore                    0.296352
# bandname_metalness_sum_zscore                              0.101768
# bandname_metalness_mean_zscore                             0.094298
# bandname_metalness_sum_div_len2_zscore                     0.099653
#
#                                          album_metalness_mean_zscore  \
# num_songs_zscore                                            0.022468
# release_year_zscore                                        -0.038621
# review_score_num_zscore                                    -0.001382
# user_review_num_zscore                                      0.012479
# user_review_score_num_zscore                                0.008844
# album_metalness_sum_zscore                                  0.877294
# album_metalness_mean_zscore                                 1.000000
# album_metalness_sum_div_len2_zscore                         0.982011
# songtitle_metalness_sum_zscore                              0.284075
# songtitle_metalness_mean_zscore                             0.277716
# songtitle_metalness_sum_div_len2_zscore                     0.305646
# bandname_metalness_sum_zscore                               0.092856
# bandname_metalness_mean_zscore                              0.091964
# bandname_metalness_sum_div_len2_zscore                      0.094439
#
#                                          album_metalness_sum_div_len2_zscore  \
# num_songs_zscore                                                    0.023494
# release_year_zscore                                                -0.041059
# review_score_num_zscore                                            -0.000846
# user_review_num_zscore                                              0.014715
# user_review_score_num_zscore                                        0.008200
# album_metalness_sum_zscore                                          0.949025
# album_metalness_mean_zscore                                         0.982011
# album_metalness_sum_div_len2_zscore                                 1.000000
# songtitle_metalness_sum_zscore                                      0.300355
# songtitle_metalness_mean_zscore                                     0.282861
# songtitle_metalness_sum_div_len2_zscore                             0.313540
# bandname_metalness_sum_zscore                                       0.099778
# bandname_metalness_mean_zscore                                      0.096181
# bandname_metalness_sum_div_len2_zscore                              0.099925
#
#                                          songtitle_metalness_sum_zscore  \
# num_songs_zscore                                               0.449803
# release_year_zscore                                           -0.084655
# review_score_num_zscore                                       -0.046577
# user_review_num_zscore                                         0.063567
# user_review_score_num_zscore                                   0.001452
# album_metalness_sum_zscore                                     0.298502
# album_metalness_mean_zscore                                    0.284075
# album_metalness_sum_div_len2_zscore                            0.300355
# songtitle_metalness_sum_zscore                                 1.000000
# songtitle_metalness_mean_zscore                                0.640576
# songtitle_metalness_sum_div_len2_zscore                        0.761088
# bandname_metalness_sum_zscore                                  0.104652
# bandname_metalness_mean_zscore                                 0.101689
# bandname_metalness_sum_div_len2_zscore                         0.105101
#
#                                          songtitle_metalness_mean_zscore  \
# num_songs_zscore                                                0.068983
# release_year_zscore                                            -0.045006
# review_score_num_zscore                                        -0.022281
# user_review_num_zscore                                          0.032759
# user_review_score_num_zscore                                    0.005876
# album_metalness_sum_zscore                                      0.264370
# album_metalness_mean_zscore                                     0.277716
# album_metalness_sum_div_len2_zscore                             0.282861
# songtitle_metalness_sum_zscore                                  0.640576
# songtitle_metalness_mean_zscore                                 1.000000
# songtitle_metalness_sum_div_len2_zscore                         0.970993
# bandname_metalness_sum_zscore                                   0.094678
# bandname_metalness_mean_zscore                                  0.094620
# bandname_metalness_sum_div_len2_zscore                          0.096718
#
#                                          songtitle_metalness_sum_div_len2_zscore  \
# num_songs_zscore                                                        0.153409
# release_year_zscore                                                    -0.056918
# review_score_num_zscore                                                -0.028331
# user_review_num_zscore                                                  0.041563
# user_review_score_num_zscore                                            0.007654
# album_metalness_sum_zscore                                              0.296352
# album_metalness_mean_zscore                                             0.305646
# album_metalness_sum_div_len2_zscore                                     0.313540
# songtitle_metalness_sum_zscore                                          0.761088
# songtitle_metalness_mean_zscore                                         0.970993
# songtitle_metalness_sum_div_len2_zscore                                 1.000000
# bandname_metalness_sum_zscore                                           0.108500
# bandname_metalness_mean_zscore                                          0.107179
# bandname_metalness_sum_div_len2_zscore                                  0.110078
#
#                                          bandname_metalness_sum_zscore  \
# num_songs_zscore                                              0.020011
# release_year_zscore                                          -0.019313
# review_score_num_zscore                                       0.008874
# user_review_num_zscore                                        0.023605
# user_review_score_num_zscore                                  0.021357
# album_metalness_sum_zscore                                    0.101768
# album_metalness_mean_zscore                                   0.092856
# album_metalness_sum_div_len2_zscore                           0.099778
# songtitle_metalness_sum_zscore                                0.104652
# songtitle_metalness_mean_zscore                               0.094678
# songtitle_metalness_sum_div_len2_zscore                       0.108500
# bandname_metalness_sum_zscore                                 1.000000
# bandname_metalness_mean_zscore                                0.923514
# bandname_metalness_sum_div_len2_zscore                        0.971233
#
#                                          bandname_metalness_mean_zscore  \
# num_songs_zscore                                               0.020656
# release_year_zscore                                           -0.029553
# review_score_num_zscore                                        0.009939
# user_review_num_zscore                                         0.048980
# user_review_score_num_zscore                                   0.037260
# album_metalness_sum_zscore                                     0.094298
# album_metalness_mean_zscore                                    0.091964
# album_metalness_sum_div_len2_zscore                            0.096181
# songtitle_metalness_sum_zscore                                 0.101689
# songtitle_metalness_mean_zscore                                0.094620
# songtitle_metalness_sum_div_len2_zscore                        0.107179
# bandname_metalness_sum_zscore                                  0.923514
# bandname_metalness_mean_zscore                                 1.000000
# bandname_metalness_sum_div_len2_zscore                         0.987942
#
#                                          bandname_metalness_sum_div_len2_zscore
# num_songs_zscore                                                       0.020677
# release_year_zscore                                                   -0.026162
# review_score_num_zscore                                                0.009673
# user_review_num_zscore                                                 0.039552
# user_review_score_num_zscore                                           0.031936
# album_metalness_sum_zscore                                             0.099653
# album_metalness_mean_zscore                                            0.094439
# album_metalness_sum_div_len2_zscore                                    0.099925
# songtitle_metalness_sum_zscore                                         0.105101
# songtitle_metalness_mean_zscore                                        0.096718
# songtitle_metalness_sum_div_len2_zscore                                0.110078
# bandname_metalness_sum_zscore                                          0.971233
# bandname_metalness_mean_zscore                                         0.987942
# bandname_metalness_sum_div_len2_zscore                                 1.000000

# %% [markdown]
# ## Linear Regression
#
# We're going to run linear regressions using both the editor review score and user review scores as our outcome measures, starting with the editor review scores. For the editor review score model we will need to drop rows that are missing editor review scores.
#
# ### Regression -- Editor review scores

# %%
model_df1 = model_df.dropna(subset = ['review_score_num_zscore'])

X1 = model_df1[['num_songs_zscore', 'release_year_zscore', 'user_review_num_zscore', 'album_metalness_sum_zscore',
             'album_metalness_mean_zscore', 'album_metalness_sum_div_len2_zscore', 'songtitle_metalness_sum_zscore',
             'songtitle_metalness_mean_zscore', 'songtitle_metalness_sum_div_len2_zscore',
             'bandname_metalness_sum_zscore', 'bandname_metalness_mean_zscore', 'bandname_metalness_sum_div_len2_zscore']]
y1 = model_df1['review_score_num_zscore']

X1a = sm.add_constant(X1)
est1 = sm.OLS(y1, X1a)
results1 = est1.fit()
print(results1.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     review_score_num_zscore   R-squared:                       0.067
# Model:                                 OLS   Adj. R-squared:                  0.066
# Method:                      Least Squares   F-statistic:                     40.78
# Date:                     Mon, 15 Oct 2018   Prob (F-statistic):           1.27e-93
# Time:                             22:30:40   Log-Likelihood:                -9260.9
# No. Observations:                     6805   AIC:                         1.855e+04
# Df Residuals:                         6792   BIC:                         1.864e+04
# Df Model:                               12
# Covariance Type:                 nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                       0.0990      0.011      8.631      0.000       0.077       0.122
# num_songs_zscore                           -0.0198      0.014     -1.380      0.168      -0.048       0.008
# release_year_zscore                        -0.1357      0.011    -12.213      0.000      -0.158      -0.114
# user_review_num_zscore                      0.1532      0.012     13.025      0.000       0.130       0.176
# album_metalness_sum_zscore                  0.2491      0.095      2.621      0.009       0.063       0.435
# album_metalness_mean_zscore                 0.3623      0.157      2.307      0.021       0.054       0.670
# album_metalness_sum_div_len2_zscore        -0.5842      0.240     -2.430      0.015      -1.055      -0.113
# songtitle_metalness_sum_zscore             -0.0762      0.025     -3.001      0.003      -0.126      -0.026
# songtitle_metalness_mean_zscore            -0.0206      0.063     -0.327      0.744      -0.144       0.103
# songtitle_metalness_sum_div_len2_zscore     0.0389      0.075      0.521      0.603      -0.108       0.185
# bandname_metalness_sum_zscore               0.0311      0.243      0.128      0.898      -0.446       0.508
# bandname_metalness_mean_zscore             -0.0309      0.366     -0.084      0.933      -0.748       0.686
# bandname_metalness_sum_div_len2_zscore      0.0068      0.594      0.011      0.991      -1.158       1.172
# ==============================================================================
# Omnibus:                     2039.807   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6917.944
# Skew:                          -1.502   Prob(JB):                         0.00
# Kurtosis:                       6.922   Cond. No.                         125.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Well that didn't work very well. Let's see if we only use one set of our metalness scores, since the different
# sets of metalness scores are highly intercorrelated. The album's mean metalness score had the highest coefficient, so let's try all of the mean scores.

# %%
X2 = model_df1[['num_songs_zscore', 'release_year_zscore', 'user_review_num_zscore',
                'album_metalness_mean_zscore', 'songtitle_metalness_mean_zscore',
                'bandname_metalness_mean_zscore']]
y2 = model_df1['review_score_num_zscore']

X2a = sm.add_constant(X2)
est2 = sm.OLS(y2, X2a)
results2 = est2.fit()
print(results2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     review_score_num_zscore   R-squared:                       0.064
# Model:                                 OLS   Adj. R-squared:                  0.063
# Method:                      Least Squares   F-statistic:                     77.76
# Date:                     Mon, 15 Oct 2018   Prob (F-statistic):           2.46e-94
# Time:                             22:30:41   Log-Likelihood:                -9271.8
# No. Observations:                     6805   AIC:                         1.856e+04
# Df Residuals:                         6798   BIC:                         1.861e+04
# Df Model:                                6
# Covariance Type:                 nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                               0.0985      0.011      8.581      0.000       0.076       0.121
# num_songs_zscore                   -0.0496      0.012     -4.101      0.000      -0.073      -0.026
# release_year_zscore                -0.1350      0.011    -12.137      0.000      -0.157      -0.113
# user_review_num_zscore              0.1511      0.012     12.861      0.000       0.128       0.174
# album_metalness_mean_zscore         0.0007      0.012      0.056      0.955      -0.023       0.024
# songtitle_metalness_mean_zscore    -0.0294      0.012     -2.418      0.016      -0.053      -0.006
# bandname_metalness_mean_zscore      0.0023      0.012      0.199      0.842      -0.021       0.025
# ==============================================================================
# Omnibus:                     2035.038   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6862.785
# Skew:                          -1.500   Prob(JB):                         0.00
# Kurtosis:                       6.899   Cond. No.                         1.47
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Regression -- User review scores
#
# For comparison, let's run a regression using user review scores as our output variable:

# %%
X3 = model_df[['num_songs_zscore', 'release_year_zscore', 'user_review_num_zscore', 'album_metalness_sum_zscore',
             'album_metalness_mean_zscore', 'album_metalness_sum_div_len2_zscore', 'songtitle_metalness_sum_zscore',
             'songtitle_metalness_mean_zscore', 'songtitle_metalness_sum_div_len2_zscore',
             'bandname_metalness_sum_zscore', 'bandname_metalness_mean_zscore', 
             'bandname_metalness_sum_div_len2_zscore']]
y3 = model_df['user_review_score_num_zscore']

X3a = sm.add_constant(X3)
est3 = sm.OLS(y3, X3a)
results3 = est3.fit()
print(results3.summary())
# Out:
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     user_review_score_num_zscore   R-squared:                       0.094
# Model:                                      OLS   Adj. R-squared:                  0.092
# Method:                           Least Squares   F-statistic:                     63.40
# Date:                          Mon, 15 Oct 2018   Prob (F-statistic):          2.55e-147
# Time:                                  22:30:42   Log-Likelihood:                -10085.
# No. Observations:                          7363   AIC:                         2.020e+04
# Df Residuals:                              7350   BIC:                         2.028e+04
# Df Model:                                    12
# Covariance Type:                      nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                       0.0025      0.011      0.229      0.819      -0.019       0.024
# num_songs_zscore                           -0.0494      0.014     -3.615      0.000      -0.076      -0.023
# release_year_zscore                        -0.1593      0.011    -14.583      0.000      -0.181      -0.138
# user_review_num_zscore                      0.2002      0.012     17.068      0.000       0.177       0.223
# album_metalness_sum_zscore                  0.0268      0.089      0.300      0.764      -0.148       0.202
# album_metalness_mean_zscore                 0.0805      0.149      0.539      0.590      -0.212       0.373
# album_metalness_sum_div_len2_zscore        -0.1061      0.228     -0.466      0.641      -0.552       0.340
# songtitle_metalness_sum_zscore             -0.0211      0.024     -0.866      0.387      -0.069       0.027
# songtitle_metalness_mean_zscore            -0.0734      0.061     -1.208      0.227      -0.193       0.046
# songtitle_metalness_sum_div_len2_zscore     0.0826      0.072      1.146      0.252      -0.059       0.224
# bandname_metalness_sum_zscore              -0.3920      0.222     -1.768      0.077      -0.827       0.043
# bandname_metalness_mean_zscore             -0.4525      0.337     -1.343      0.179      -1.113       0.208
# bandname_metalness_sum_div_len2_zscore      0.8483      0.545      1.556      0.120      -0.221       1.917
# ==============================================================================
# Omnibus:                     3679.696   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            38741.699
# Skew:                          -2.152   Prob(JB):                         0.00
# Kurtosis:                      13.380   Cond. No.                         119.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Let's try a subset of metalness scores again. This time it's our sum divided by half the length score that has the best coefficient (for the band name this time), so let's try that set.

# %%
X4 = model_df[['num_songs_zscore', 'release_year_zscore', 'user_review_num_zscore',
                'album_metalness_sum_div_len2_zscore', 'songtitle_metalness_sum_div_len2_zscore',
                'bandname_metalness_sum_div_len2_zscore']]
y4 = model_df['user_review_score_num_zscore']

X4a = sm.add_constant(X4)
est4 = sm.OLS(y4, X4a)
results4 = est4.fit()
print(results4.summary())
# Out:
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     user_review_score_num_zscore   R-squared:                       0.093
# Model:                                      OLS   Adj. R-squared:                  0.092
# Method:                           Least Squares   F-statistic:                     125.4
# Date:                          Mon, 15 Oct 2018   Prob (F-statistic):          1.78e-151
# Time:                                  22:30:43   Log-Likelihood:                -10089.
# No. Observations:                          7363   AIC:                         2.019e+04
# Df Residuals:                              7356   BIC:                         2.024e+04
# Df Model:                                     6
# Covariance Type:                      nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                       0.0026      0.011      0.232      0.816      -0.019       0.024
# num_songs_zscore                           -0.0510      0.012     -4.385      0.000      -0.074      -0.028
# release_year_zscore                        -0.1596      0.011    -14.612      0.000      -0.181      -0.138
# user_review_num_zscore                      0.2012      0.012     17.188      0.000       0.178       0.224
# album_metalness_sum_div_len2_zscore        -0.0012      0.012     -0.105      0.916      -0.024       0.022
# songtitle_metalness_sum_div_len2_zscore    -0.0049      0.012     -0.406      0.685      -0.028       0.019
# bandname_metalness_sum_div_len2_zscore      0.0214      0.011      1.889      0.059      -0.001       0.044
# ==============================================================================
# Omnibus:                     3680.385   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            38716.987
# Skew:                          -2.153   Prob(JB):                         0.00
# Kurtosis:                      13.376   Cond. No.                         1.53
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# This isn't looking particularly promising, although at least the number of user reviews seems to have a consistently decent coefficiant (at least compared to everything else).
#
# However, just for fun let's run one using only one set of metalness scores.
#
# ### Regression -- User review scores using only metalness scores

# %%
X5 = model_df[['album_metalness_sum_div_len2_zscore', 'songtitle_metalness_sum_div_len2_zscore',
             'bandname_metalness_sum_div_len2_zscore']]
y5 = model_df['user_review_score_num_zscore']

X5a = sm.add_constant(X5)
est5 = sm.OLS(y5, X5a)
results5 = est5.fit()
print(results5.summary())
# Out:
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     user_review_score_num_zscore   R-squared:                       0.001
# Model:                                      OLS   Adj. R-squared:                  0.001
# Method:                           Least Squares   F-statistic:                     2.585
# Date:                          Mon, 15 Oct 2018   Prob (F-statistic):             0.0514
# Time:                                  22:30:44   Log-Likelihood:                -10443.
# No. Observations:                          7363   AIC:                         2.089e+04
# Df Residuals:                              7359   BIC:                         2.092e+04
# Df Model:                                     3
# Covariance Type:                      nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                      -0.0006      0.012     -0.048      0.962      -0.023       0.022
# album_metalness_sum_div_len2_zscore         0.0042      0.012      0.339      0.735      -0.020       0.028
# songtitle_metalness_sum_div_len2_zscore     0.0029      0.012      0.237      0.813      -0.021       0.027
# bandname_metalness_sum_div_len2_zscore      0.0316      0.012      2.655      0.008       0.008       0.055
# ==============================================================================
# Omnibus:                     3391.727   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30085.021
# Skew:                          -1.998   Prob(JB):                         0.00
# Kurtosis:                      12.061   Cond. No.                         1.41
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Regression -- User review scores using only other album metadata
#
# It's pretty clear that the metalness scores have no predictive value for either of our prospective outcome variables.
#
# However, the above regressions show two slightly interesting results: the album year is negatively correlated with rating (meaning older albums were rated higher), and the number of user reviews is correlated with both user and editor ratings. The latter seems not to be particularly predictive, since it would make sense if better albums attract more users to the album's page to share their opinion. The former may indicate that site editors became slightly harsher raters over the course of the site's existence.
#
# Just for fun let's run the model with just these two predictors, separately and then together.

# %%
X6 = model_df[['release_year_zscore']]
y6 = model_df['user_review_score_num_zscore']

X6a = sm.add_constant(X6)
est6 = sm.OLS(y6, X6a)
results6 = est6.fit()
print(results6.summary())
# Out:
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     user_review_score_num_zscore   R-squared:                       0.054
# Model:                                      OLS   Adj. R-squared:                  0.053
# Method:                           Least Squares   F-statistic:                     416.1
# Date:                          Mon, 15 Oct 2018   Prob (F-statistic):           5.04e-90
# Time:                                  22:30:45   Log-Likelihood:                -10245.
# No. Observations:                          7363   AIC:                         2.049e+04
# Df Residuals:                              7361   BIC:                         2.051e+04
# Df Model:                                     1
# Covariance Type:                      nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0019      0.011      0.165      0.869      -0.020       0.024
# release_year_zscore    -0.2155      0.011    -20.399      0.000      -0.236      -0.195
# ==============================================================================
# Omnibus:                     3552.588   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33721.510
# Skew:                          -2.094   Prob(JB):                         0.00
# Kurtosis:                      12.611   Cond. No.                         1.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X7 = model_df[['user_review_num_zscore']]
y7 = model_df['user_review_score_num_zscore']

X7a = sm.add_constant(X7)
est7 = sm.OLS(y7, X7a)
results7 = est7.fit()
print(results7.summary())
# Out:
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     user_review_score_num_zscore   R-squared:                       0.064
# Model:                                      OLS   Adj. R-squared:                  0.064
# Method:                           Least Squares   F-statistic:                     505.4
# Date:                          Mon, 15 Oct 2018   Prob (F-statistic):          2.67e-108
# Time:                                  22:30:46   Log-Likelihood:                -10203.
# No. Observations:                          7363   AIC:                         2.041e+04
# Df Residuals:                              7361   BIC:                         2.042e+04
# Df Model:                                     1
# Covariance Type:                      nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                  -3.217e-14      0.011  -2.85e-12      1.000      -0.022       0.022
# user_review_num_zscore     0.2535      0.011     22.480      0.000       0.231       0.276
# ==============================================================================
# Omnibus:                     3629.350   Durbin-Watson:                   1.924
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37699.200
# Skew:                          -2.119   Prob(JB):                         0.00
# Kurtosis:                      13.243   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X8 = model_df[['release_year_zscore', 'user_review_num_zscore']]
y8 = model_df['user_review_score_num_zscore']

X8a = sm.add_constant(X8)
est8 = sm.OLS(y8, X8a)
results8 = est8.fit()
print(results8.summary())
# Out:
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     user_review_score_num_zscore   R-squared:                       0.090
# Model:                                      OLS   Adj. R-squared:                  0.090
# Method:                           Least Squares   F-statistic:                     363.3
# Date:                          Mon, 15 Oct 2018   Prob (F-statistic):          3.32e-151
# Time:                                  22:30:47   Log-Likelihood:                -10101.
# No. Observations:                          7363   AIC:                         2.021e+04
# Df Residuals:                              7360   BIC:                         2.023e+04
# Df Model:                                     2
# Covariance Type:                      nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.0014      0.011      0.123      0.902      -0.020       0.023
# release_year_zscore       -0.1570      0.011    -14.392      0.000      -0.178      -0.136
# user_review_num_zscore     0.2007      0.012     17.145      0.000       0.178       0.224
# ==============================================================================
# Omnibus:                     3686.031   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            38933.355
# Skew:                          -2.156   Prob(JB):                         0.00
# Kurtosis:                      13.407   Cond. No.                         1.39
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# It sure looks like these two variables are much better predictors of album ratings than any of our metalness scores. Too bad! But I think that in and of itself is a pretty interesting finding.
#
# Let's visualize how these two predictors relate to the average user review score -- but we will go back to the non-standardized variables, which we will do in another notebook.
